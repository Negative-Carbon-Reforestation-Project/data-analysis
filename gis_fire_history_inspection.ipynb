# %%
import pandas as pd

# %%
df = pd.read_csv('./data/unprocessed/Fire_History.csv')
df
# Out:
#       OBJECTID poly_IncidentName           poly_FeatureCategory  \
# 0          127           Coleman  Wildfire Daily Fire Perimeter
# 1          128          Patrick   Wildfire Daily Fire Perimeter
# 2          129           Low Top  Wildfire Daily Fire Perimeter
# 3          130           Sloan 2  Wildfire Daily Fire Perimeter
# 4          133       Bloody nose  Wildfire Daily Fire Perimeter
# ...        ...               ...                            ...
# 8674     14325           Firebox  Wildfire Daily Fire Perimeter
# 8675     14326       MCBEE GRADE  Wildfire Daily Fire Perimeter
# 8676     14327             FT 16  Wildfire Daily Fire Perimeter
# 8677     14328     THREE SPRINGS  Wildfire Daily Fire Perimeter
# 8678     14329         BIG GULCH  Wildfire Daily Fire Perimeter
#
#       poly_MapMethod  poly_GISAcres      poly_CreateDate     poly_DateCurrent  \
# 0      Mixed Methods     562.913504  2021/05/04 22:50:38  2021/05/04 22:50:38
# ...
